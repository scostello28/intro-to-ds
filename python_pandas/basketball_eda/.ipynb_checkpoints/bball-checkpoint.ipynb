# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
df = pd.read_csv('player_data.csv')

# %%
df.head()
# Out:
#                Player   G    GS    MP    FG   FGA    2P   2PA   3P   3PA  \
# 0     Julian Edmonson  30   5.0   568  10.5  26.2   6.2  15.2  4.3  11.0
# 1     Jacob Lancaster  31  11.0   434  12.0  21.7  11.8  21.5  0.1   0.1
# 2        Parker Wentz  31  29.0  1040   7.7  15.7   3.2   5.6  4.5  10.1
# 3  LaDarrien Williams  16  14.0   474   8.1  21.8   6.4  16.3  1.7   5.5
# 4    Harrison Hawkins  16  16.0   481   6.8  18.1   3.7  10.4  3.1   7.6
#
#     ...    AST  STL  BLK  TOV   PF               Team  Season  Class Pos  \
# 0   ...    3.0  2.3  0.2  5.6  6.6  abilene-christian    2014    3.0   G
# 1   ...    1.0  1.0  5.0  5.6  6.7  abilene-christian    2014    3.0   F
# 2   ...    4.9  2.8  0.1  3.4  4.0  abilene-christian    2014    2.0   G
# 3   ...    7.7  2.4  0.5  4.2  5.2  abilene-christian    2014    3.0   G
# 4   ...    6.3  2.1  0.0  6.0  5.8  abilene-christian    2014    3.0   G
#
#    Height
# 0    73.0
# 1    82.0
# 2    69.0
# 3    72.0
# 4    72.0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23868 entries, 0 to 23867
# Data columns (total 23 columns):
# Player    23868 non-null object
# G         23868 non-null int64
# GS        23867 non-null float64
# MP        23868 non-null int64
# FG        23744 non-null float64
# FGA       23744 non-null float64
# 2P        23744 non-null float64
# 2PA       23744 non-null float64
# 3P        23744 non-null float64
# 3PA       23744 non-null float64
# FT        23744 non-null float64
# FTA       23744 non-null float64
# TRB       23744 non-null float64
# AST       23744 non-null float64
# STL       23744 non-null float64
# BLK       23744 non-null float64
# TOV       23744 non-null float64
# PF        23744 non-null float64
# Team      23868 non-null object
# Season    23868 non-null int64
# Class     23311 non-null float64
# Pos       23311 non-null object
# Height    23311 non-null float64
# dtypes: float64(17), int64(3), object(3)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#                   G            GS            MP            FG           FGA  \
# count  23868.000000  23867.000000  23868.000000  23744.000000  23744.000000
# mean      24.359770     12.016592    485.537791      6.331006     15.279127
# std       10.496075     12.947851    369.624537      3.362839      6.736971
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%       17.000000      0.000000    123.000000      4.400000     11.300000
# 50%       29.000000      6.000000    459.000000      6.300000     15.100000
# 75%       32.000000     25.000000    805.000000      8.200000     18.800000
# max       41.000000     41.000000   1474.000000     63.400000    126.800000
#
#                  2P           2PA            3P           3PA            FT  \
# count  23744.000000  23744.000000  23744.000000  23744.000000  23744.000000
# mean       4.583137      9.684990      1.747545      5.594500      3.611801
# std        3.206025      5.718717      2.063585      5.509197      3.123368
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.400000      6.000000      0.000000      0.600000      1.800000
# 50%        4.300000      9.300000      1.300000      4.900000      3.200000
# 75%        6.300000     12.900000      2.900000      8.800000      4.900000
# max       63.400000    126.800000     56.700000    122.900000    113.600000
#
#                 FTA           TRB           AST           STL           BLK  \
# count  23744.000000  23744.000000  23744.000000  23744.000000  23744.000000
# mean       5.549212      9.475425      3.296319      1.704443      1.018299
# std        4.614641      5.452278      2.837091      1.856055      1.516546
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      5.800000      1.400000      0.900000      0.000000
# 50%        5.000000      8.700000      2.700000      1.500000      0.500000
# 75%        7.400000     12.500000      4.500000      2.200000      1.400000
# max      125.200000     86.500000     61.100000     64.800000     59.500000
#
#                 TOV            PF        Season         Class        Height
# count  23744.000000  23744.000000  23868.000000  23311.000000  23311.000000
# mean       3.668341      6.286965   2015.999623      2.455965     76.819828
# std        3.061034      4.307453      1.412924      1.115557      3.518153
# min        0.000000      0.000000   2014.000000      1.000000     62.000000
# 25%        2.500000      4.200000   2015.000000      1.000000     74.000000
# 50%        3.400000      5.600000   2016.000000      2.000000     77.000000
# 75%        4.500000      7.700000   2017.000000      3.000000     80.000000
# max      171.300000    245.500000   2018.000000      4.000000     91.000000

# %%
# cols = df.columns.tolist()
# cols = [col.lower() for col in cols]
# cols = [col.strip() for col in cols]
# df.columns = cols
# df.columns

# %% [markdown]
# **Feature Engineering**
# 1. Create FG_perc, 2P_perc, 3P_perc, FT_perc and Points Columns

# %%
# FG_perc
df['FG_perc'] = df['FG'] / df['FGA']

# 2P_perc
df['2P_perc'] = df['2P'] / df['2PA']

# 3P_perc
df['3P_perc'] = df['3P'] / df['3PA']

# FT_perc
df['FT_perc'] = df['FT'] / df['FTA']

# FT_perc
df['Points'] = df['FT'] +  df['2P'] * 2 + df['3P'] * 3

# %%
df[['FG_perc', '2P_perc', '3P_perc', 'FT_perc', 'Points']].head()
# Out:
#     FG_perc   2P_perc   3P_perc   FT_perc  Points
# 0  0.400763  0.407895  0.390909  0.744000    34.6
# 1  0.552995  0.548837  1.000000  0.632911    28.9
# 2  0.490446  0.571429  0.445545  0.865385    24.4
# 3  0.371560  0.392638  0.309091  0.714286    24.4
# 4  0.375691  0.355769  0.407895  0.852273    24.2

# %% [markdown]
# **Query Questions**
# 1. How many teams are there?
# 2. Senior Center with most turn overs before 2017.
# 3. Team with most points by under classmen.
# 4. Player under 6 feet tall with most fouls.
# 5. Guards from each season in top 10% for three-point shot percentage from the 2018 season.

# %%
# 1. How many teams are there?
len(df.Team.unique())
# Out:
# 351

# %%
# 2. Senior Center with most turn overs before 2017.
no2_df = df[(df['Class'] == 4) & (df['Pos'] == 'C') & (df['Season'] < 2017)]
no2_df = no2_df[['Team', 'Player', 'TOV']].groupby('Player').sum().reset_index()
no2_df.sort_values('TOV', ascending=False).iloc[0]
# Out:
# Player    Arthur Gage
# TOV              57.5
# Name: 16, dtype: object

# %%
# 3. Team with most points by under classmen since 2016.
no3_df = df[(df['Class'] < 3) & (df['Season'] >= 2016)]
no3_df = no3_df.groupby('Team').sum()['Points']
no3_df[no3_df == no3_df.max()]
# Out:
# Team
# citadel    661.6
# Name: Points, dtype: float64

# %%
# 4. 5 players under 6 feet tall with most fouls
no4_df = df[df['Height'] < 72].groupby('Player').sum()['PF']
no4_df.sort_values(ascending=False).iloc[:5]
# Out:
# Player
# Hank Davis         70.3
# Jason Boswell      59.4
# Casey Perrin       53.3
# Jay Jay Davis      47.7
# Kendall Jackson    39.2
# Name: PF, dtype: float64

# %%
# 5. Guards in top 10% for three-point shot percentage from the 2018 season.
no5_df = df[(df['Season'] == 2018) & (df['Pos'] == 'G')]
no5_df = no5_df[['Team', 'G', 'MP','Player', '3P', '3PA','3P_perc']]
no5_df = no5_df[no5_df['MP'] > 250]
no5_df[no5_df['3P_perc'] >= no5_df['3P_perc'].quantile(.1)].sort_values('3P_perc', ascending=False).reset_index(drop=True)
# Out:
#                                 Team   G    MP             Player   3P   3PA  \
# 0                           monmouth  31   405     Marcus McClary  0.3   0.4
# 1             north-carolina-central  23   316       Alston Jones  1.1   1.5
# 2                 south-dakota-state  23   300       Chris Howell  0.4   0.6
# 3                           winthrop  26   294     Charles Falden  3.2   5.8
# 4                     kennesaw-state  30  1102     Nick Masterson  3.7   6.9
# 5                          charlotte   9   258       Hudson Price  2.4   4.5
# 6                       william-mary  31   945  Connor Burchfield  5.3  10.1
# 7                 south-dakota-state  34   501       Lane Severyn  2.4   4.6
# 8                              siena  29   328  Christian Bentley  1.3   2.5
# 9                        idaho-state  27   889     Jared Stutzman  4.2   8.1
# 10                           bradley  27   271   Ryan Stipanovich  3.1   6.0
# 11                    michigan-state  35   985    Cassius Winston  4.5   9.0
# 12                              njit  30   671      Shyquan Gibbs  2.0   4.0
# 13                florida-gulf-coast  27   506  Christian Carlyle  1.0   2.0
# 14                         loyola-md  26   457         Sam Norton  0.5   1.0
# 15                  saint-francis-pa  31   899      Andre Wolford  6.1  12.3
# 16                south-dakota-state  35   922     Skyler Flatten  3.3   6.7
# 17                        evansville  22   665          Dru Smith  2.5   5.1
# 18    southern-illinois-edwardsville  26   749      Justin Benton  1.9   3.9
# 19                         marquette  35  1141         Sam Hauser  4.7   9.7
# 20                          davidson  33   629       Rusty Reigel  2.7   5.6
# 21              east-tennessee-state  32   347     Jason Williams  4.0   8.3
# 22                        binghamton  31   736      Everson Davis  1.3   2.7
# 23                            butler  35   531      Henry Baddley  2.2   4.6
# 24                            nevada  37   743      Hallice Cooke  3.3   6.9
# 25                           vermont  35   990     Everett Duncan  3.2   6.7
# 26                       weber-state  31   789        Dusty Baker  3.2   6.7
# 27                  georgia-southern  32  1035       Tookie Brown  2.7   5.7
# 28                     massachusetts  33  1031        Carl Pierre  5.3  11.2
# 29                        new-mexico  34   762     Anthony Mathis  7.0  14.8
# ...                              ...  ..   ...                ...  ...   ...
# 1513        north-carolina-asheville  32  1028       Ahmad Thomas  0.9   3.5
# 1514                        la-salle  28   330     Johnnie Shuler  1.8   7.0
# 1515                     mississippi  32   604    Devontae Shuler  2.8  10.9
# 1516                           brown  24   600         Obi Okolie  1.0   3.9
# 1517                     texas-state  31   339       Shelby Adams  1.1   4.3
# 1518                     st-johns-ny  30  1110     Shamorie Ponds  2.4   9.4
# 1519                   texas-el-paso  27   296       Trey Touchet  1.2   4.7
# 1520                   alabama-state  31   567         Gene Davis  1.3   5.1
# 1521            east-tennessee-state  34   698      Jermaine Long  1.6   6.3
# 1522           florida-international  31  1114    Brian Beard Jr.  1.9   7.5
# 1523                      ohio-state  33   462        Musa Jallow  1.4   5.6
# 1524              southern-methodist  33  1096        Jimmy Whitt  0.3   1.2
# 1525             charleston-southern  28   635    Cortez Mitchell  1.1   4.4
# 1526                long-beach-state  31   551     Jordan Roberts  0.1   0.4
# 1527                        lipscomb  31   845       Kenny Cooper  0.9   3.6
# 1528                         liberty  30   416    Isaiah Williams  0.4   1.6
# 1529                     new-orleans  33   652         Troy Green  0.4   1.6
# 1530                     new-orleans  33   505      Damion Rosser  0.2   0.8
# 1531                        michigan  31   311         Eli Brooks  2.0   8.0
# 1532                        miami-oh  32   918       Jalen Adaway  1.1   4.4
# 1533                 cleveland-state  35   737     Kasheem Thomas  1.2   4.8
# 1534                      kent-state  33   629     Mitch Peterson  1.4   5.6
# 1535                   northern-iowa  32   951    Tywhon Pickford  2.0   8.0
# 1536                         alabama  35   741         Herb Jones  0.5   2.0
# 1537                          temple  27   350        Alani Moore  2.5  10.0
# 1538                      california  30   943        Don Coleman  1.6   6.4
# 1539               north-carolina-at  33   322     Amari Hamilton  4.2  16.8
# 1540                florida-atlantic  28   723      Payton Hulsey  0.5   2.0
# 1541              northwestern-state  27   683   Iziahiah Sweeney  1.7   6.8
# 1542             bowling-green-state  30   396     Nelly Cummings  1.4   5.6
#
#        3P_perc
# 0     0.750000
# 1     0.733333
# 2     0.666667
# 3     0.551724
# 4     0.536232
# 5     0.533333
# 6     0.524752
# 7     0.521739
# 8     0.520000
# 9     0.518519
# 10    0.516667
# 11    0.500000
# 12    0.500000
# 13    0.500000
# 14    0.500000
# 15    0.495935
# 16    0.492537
# 17    0.490196
# 18    0.487179
# 19    0.484536
# 20    0.482143
# 21    0.481928
# 22    0.481481
# 23    0.478261
# 24    0.478261
# 25    0.477612
# 26    0.477612
# 27    0.473684
# 28    0.473214
# 29    0.472973
# ...        ...
# 1513  0.257143
# 1514  0.257143
# 1515  0.256881
# 1516  0.256410
# 1517  0.255814
# 1518  0.255319
# 1519  0.255319
# 1520  0.254902
# 1521  0.253968
# 1522  0.253333
# 1523  0.250000
# 1524  0.250000
# 1525  0.250000
# 1526  0.250000
# 1527  0.250000
# 1528  0.250000
# 1529  0.250000
# 1530  0.250000
# 1531  0.250000
# 1532  0.250000
# 1533  0.250000
# 1534  0.250000
# 1535  0.250000
# 1536  0.250000
# 1537  0.250000
# 1538  0.250000
# 1539  0.250000
# 1540  0.250000
# 1541  0.250000
# 1542  0.250000
#
# [1543 rows x 7 columns]

# %% [markdown]
# **Basic EDA**
# 1. What columns do we have?
# 2. How much missing data do I have?
# 3. Where is this missing data?

# %%
# 1. What columns do we have?
df.columns
# Out:
# Index(['Player', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT',
#        'FTA', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'Team', 'Season',
#        'Class', 'Pos', 'Height', 'FG_perc', '2P_perc', '3P_perc', 'FT_perc',
#        'Points'],
#       dtype='object')

# %%
# 2. How much missing data do I have?
null_data = df[df.isnull().any(axis=1)]
len(null_data)
# Out:
# 6398

# %%
null_data.describe()
# Out:
#                  G           GS           MP           FG          FGA  \
# count  6398.000000  6397.000000  6398.000000  6274.000000  6274.000000
# mean     15.995936     5.234016   206.731010     5.301020    13.006662
# std      11.803097     9.771328   271.207974     4.790788     9.733048
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     0.000000    11.000000     1.900000     7.700000
# 50%      13.000000     0.000000    56.000000     5.000000    11.700000
# 75%      28.000000     5.000000   339.750000     7.600000    16.375000
# max      40.000000    40.000000  1474.000000    63.400000   126.800000
#
#                 2P          2PA           3P          3PA           FT  \
# count  6274.000000  6274.000000  6274.000000  6274.000000  6274.000000
# mean      4.501036     9.650207     0.799920     3.356073     2.695473
# std       4.462879     8.014881     2.671654     7.484279     4.406510
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     4.500000     0.000000     0.000000     0.000000
# 50%       4.200000     9.300000     0.000000     0.000000     1.800000
# 75%       7.000000    13.700000     0.000000     3.300000     4.000000
# max      63.400000   126.800000    56.700000   122.900000   113.600000
#
#           ...               TOV           PF       Season        Class  \
# count     ...       6274.000000  6274.000000  6398.000000  5841.000000
# mean      ...          3.835496     7.809531  2015.997812     2.330936
# std       ...          5.335144     7.118793     1.437564     1.113837
# min       ...          0.000000     0.000000  2014.000000     1.000000
# 25%       ...          1.200000     4.400000  2015.000000     1.000000
# 50%       ...          3.200000     7.500000  2016.000000     2.000000
# 75%       ...          4.700000    10.300000  2017.000000     3.000000
# max       ...        171.300000   245.500000  2018.000000     4.000000
#
#             Height      FG_perc      2P_perc      3P_perc      FT_perc  \
# count  5841.000000  5721.000000  5180.000000  1746.000000  3971.000000
# mean     78.227701     0.430578     0.464326     0.245495     0.545332
# std       3.832744     0.244268     0.251839     0.289292     0.219116
# min      62.000000     0.000000     0.000000     0.000000     0.000000
# 25%      76.000000     0.301282     0.359532     0.000000     0.455882
# 50%      79.000000     0.483221     0.500000     0.200000     0.555556
# 75%      81.000000     0.569343     0.587476     0.381913     0.666667
# max      90.000000     1.000000     1.000000     1.000000     1.000000
#
#             Points
# count  6274.000000
# mean     14.097306
# std      12.002280
# min       0.000000
# 25%       6.500000
# 50%      13.200000
# 75%      19.600000
# max     170.100000
#
# [8 rows x 25 columns]

# %%
null_data['G'].mean()
# Out:
# 15.995936230071898

# %%
# drop NaNs
non_null_data = df.dropna()

# %%
non_null_data['G'].mean()
# Out:
# 27.42283915283343

# %% [markdown]
# **Basic plotting**
# 1. Create a df for 2018 Season with only MP, FG, 2P, 3P
# 2. Create histograms for MP, FG, 2P, 3P
# 3. Create box plots for MP, FG, 2P, 3P
# 4. Scatter FG, 2P and 3P by MP.
# 5. Make a scatter matrix.

# %%
df_2018_wn = df[(df['Season'] == 2018) & (df['MP'] > 250)]
df_2018 = df[(df['Season'] == 2018) & (df['MP'] > 250)].dropna()

# %%
df_2018.MP.hist(bins=100);

# %%
df_2018_wn.MP.hist(bins=100);
